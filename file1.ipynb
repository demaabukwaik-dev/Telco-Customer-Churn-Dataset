# %% [markdown]
# Phase 1

# %%
import pandas as pd 
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
df.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df["Churn"].value_counts(dropna=False)
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
#imbalanced

# %%
'''
This telecom company dataset describes the customers including their personal info, the duration they have spent with the company,
the services they use and the financial relationship between the customer and the company.

Our target is to answer to the question: "Why customers leave the company and who are they?" based on deep data analysis.
This enables us to develope comprehensive strategies to reduce customer loss. 

From the initial overview on the dataset, some issues were observed. First, "SeniorCitizen" should be converted from numeric to bool.
Second, the "TotalCharges" column should be converted from str to numeric type. Third, the "churn" column should be converted from str to bool.
Finally, the "churn" target variable is imbalanced

'''

# %% [markdown]
# phase 2

# %%
Create a table:

Column	Current dtype	Correct type	Reason
Focus on:

IDs (like customerID)
Binary columns (Yes/No)
Columns stored as text but should be numeric (common issue: TotalCharges)
Deliverable
A column audit table
3 columns that can easily cause wrong analysis if typed incorrectly

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df["customerID"].isna().sum()
# Out:
# np.int64(0)

# %%
df[["customerID"]].nunique()
# Out:
# customerID    7043
# dtype: int64

# %%
df["gender"].value_counts(dropna=False)
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
'''
check all values have (0,1) representing (true,false) --> convert to bool
check all values  have (yes/no)  only --> convert to bool
"SeniorCitizen"  int 
"Partner", "Dependents", "PhoneService", "PaperlessBilling","Churn" 
'''
# Out:
# '\ncheck all values have (0,1) representing (true,false) --> convert to bool\ncheck all values  have (yes/no)  only --> convert to bool\n"SeniorCitizen"  int \n"Partner", "Dependents", "PhoneService", "PaperlessBilling","Churn" \n'

# %%
# convert int --> bool
df["SeniorCitizen"].value_counts(dropna=False)

# %%
df["SeniorCitizen"] = df["SeniorCitizen"].astype(bool)

# %%
# convert str --> bool 
df["Partner"].value_counts(dropna=False)
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
df["Partner"] = df["Partner"].astype(bool)

# %%
# convert str --> bool 
df["Dependents"].value_counts(dropna=False)
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
df["Dependents"] = df["Dependents"].astype(bool)

# %%
# convert str --> bool 
df["PhoneService"].value_counts(dropna=False)
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
df["PhoneService"] = df["PhoneService"].astype(bool)

# %%
# dont convert str --> bool 
df["MultipleLines"].value_counts(dropna=False)
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
# dont convert str --> bool 
df["InternetService"].value_counts(dropna=False)
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
# dont convert str --> bool 
df["OnlineSecurity"].value_counts(dropna=False)
# Out:
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64

# %%
# dont convert str --> bool 
df["DeviceProtection"].value_counts(dropna=False)
# Out:
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64

# %%
# dont convert str --> bool 
df["TechSupport"].value_counts(dropna=False)
# Out:
# TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
# dont convert str --> bool 
df["StreamingTV"].value_counts(dropna=False)
# Out:
# StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64

# %%
# dont convert str --> bool 
df["StreamingMovies"].value_counts(dropna=False)
# Out:
# StreamingMovies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: count, dtype: int64

# %%
# convert str --> bool 
df["PaperlessBilling"].value_counts(dropna=False)
# Out:
# PaperlessBilling
# Yes    4171
# No     2872
# Name: count, dtype: int64

# %%
df[["PhoneService" , "Churn"]] = df[["PhoneService" , "Churn"]].astype(bool)

# %%
df["Contract"].value_counts(dropna=False)
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df["tenure"].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
df["PaymentMethod"].value_counts(dropna=False)
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
df["MonthlyCharges"].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors= "coerce")
df["TotalCharges"].dtype
# Out:
# dtype('float64')

# %%
df["TotalCharges"].describe()
# Out:
# count    7032.000000
# mean     2283.300441
# std      2266.771362
# min        18.800000
# 25%       401.450000
# 50%      1397.475000
# 75%      3794.737500
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
# convert str --> bool 
df["Churn"].value_counts(dropna=False)
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...
